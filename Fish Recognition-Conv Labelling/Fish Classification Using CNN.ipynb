# %%
#import basic libaries
import tensorflow as tf
import cv2 #to do some image operations (cv2=OpenCv)
import os #to iterate through directories and join paths
import numpy as np #to do various array of operations (numpy=numerical python)

#import plot to show the image
import matplotlib.pyplot as plt

#import image
from tensorflow.keras.preprocessing import image

#import image data generator untuk mengenerate label otomatis sesuai nama folder dmn image tsb berada
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#loading images
img = image.load_img("basedata/training/Nin/1.PNG")

# %%
#showing the image
plt.imshow(img)

# %%
#showing the size of image
cv2.imread("basedata/training/Nin/1.PNG").shape #will be shown in high, width, channel

# %%
#showing the size of image
cv2.imread("basedata/training/Nin/1.PNG") #showing image in 3 dimentional matrics

# %%
#generating training and validation dataset dg ImageDataGenerator
#rescale=1/255 akan membuat image menjadi hitam putih. Karena image RGB bernilai 0-255. Dg membagi 255, maka nilainya akan menjadi 0 dan 1
train = ImageDataGenerator(rescale=1/255)
validation = ImageDataGenerator(rescale=1/255)

# %%
#convert training images to fit for the neural network
train_dataset = train.flow_from_directory('basedata/training',
                                         target_size = (500,500),
                                         batch_size = 3,)
#flow from directory akan mengenerate label otomatis dari nama folder
#untuk memasukkan ke NN tidak bisa size yang bervariasi, jadi harus di resize
#karena jumlah image tidak banyak, maka batch size cukup di set 3
validation_dataset = train.flow_from_directory('basedata/validation',
                                         target_size = (500,500),
                                         batch_size = 3,)
# Out:
# Found 58 images belonging to 4 classes.
# Found 25 images belonging to 4 classes.

# %%
#untuk mengetahui label kelas
train_dataset.class_indices
# Out:
# {'Nin': 0, 'Nuanchan': 1, 'Tapian': 2, 'Yeesok': 3}

# %%
#define the model
model = tf.keras.models.Sequential([tf.keras.layers.Conv2D(16,(3,3),activation = 'relu',input_shape = (500,500,3)),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(32,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(64,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    ##
                                    tf.keras.layers.Flatten(),
                                    ##
                                    tf.keras.layers.Dense(512,activation = 'relu'),
                                    ##
                                    tf.keras.layers.Dense(1,activation = 'sigmoid')
                                   ])
#layer pertama adalah Conv2D (konvolusi 2 dimensi) dg jumlah 16 dg size masing2 3x3.

# %%
#compiling model
model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])

# %%
#fit up the model and start training
model_fit = model.fit(train_dataset,
                      steps_per_epoch = 3,
                      epochs = 30,
                      validation_data = validation_dataset)
# Out:
# Epoch 1/30
# 3/3 [==============================] - 2s 822ms/step - loss: 0.5639 - accuracy: 0.7500 - val_loss: 0.5670 - val_accuracy: 0.7500
# Epoch 2/30
# 3/3 [==============================] - 2s 818ms/step - loss: 0.5675 - accuracy: 0.7500 - val_loss: 0.5789 - val_accuracy: 0.7500
# Epoch 3/30
# 3/3 [==============================] - 2s 824ms/step - loss: 0.6083 - accuracy: 0.7500 - val_loss: 0.6126 - val_accuracy: 0.7500
# Epoch 4/30
# 3/3 [==============================] - 2s 820ms/step - loss: 0.5796 - accuracy: 0.7500 - val_loss: 0.5756 - val_accuracy: 0.7500
# Epoch 5/30
# 3/3 [==============================] - 2s 798ms/step - loss: 0.5726 - accuracy: 0.7500 - val_loss: 0.5702 - val_accuracy: 0.7500
# Epoch 6/30
# 3/3 [==============================] - 2s 800ms/step - loss: 0.5673 - accuracy: 0.7500 - val_loss: 0.5723 - val_accuracy: 0.7500
# Epoch 7/30
# 3/3 [==============================] - 2s 823ms/step - loss: 0.5674 - accuracy: 0.7500 - val_loss: 0.5671 - val_accuracy: 0.7500
# Epoch 8/30
# 3/3 [==============================] - 2s 818ms/step - loss: 0.5654 - accuracy: 0.7500 - val_loss: 0.5897 - val_accuracy: 0.7500
# Epoch 9/30
# 3/3 [==============================] - 2s 813ms/step - loss: 0.5917 - accuracy: 0.7500 - val_loss: 0.5649 - val_accuracy: 0.7500
# Epoch 10/30
# 3/3 [==============================] - 2s 794ms/step - loss: 0.5642 - accuracy: 0.7500 - val_loss: 0.5670 - val_accuracy: 0.7500
# Epoch 11/30
# 3/3 [==============================] - 2s 809ms/step - loss: 0.5738 - accuracy: 0.7500 - val_loss: 0.6041 - val_accuracy: 0.7500
# Epoch 12/30
# 3/3 [==============================] - 2s 826ms/step - loss: 0.6224 - accuracy: 0.7500 - val_loss: 0.6198 - val_accuracy: 0.7500
# Epoch 13/30
# 3/3 [==============================] - 2s 804ms/step - loss: 0.5889 - accuracy: 0.7500 - val_loss: 0.5683 - val_accuracy: 0.7500
# Epoch 14/30
# 3/3 [==============================] - 2s 828ms/step - loss: 0.5648 - accuracy: 0.7500 - val_loss: 0.5657 - val_accuracy: 0.7500
# Epoch 15/30
# 3/3 [==============================] - 2s 844ms/step - loss: 0.5653 - accuracy: 0.7500 - val_loss: 0.5701 - val_accuracy: 0.7500
# Epoch 16/30
# 3/3 [==============================] - 2s 875ms/step - loss: 0.5700 - accuracy: 0.7500 - val_loss: 0.5727 - val_accuracy: 0.7500
# Epoch 17/30
# 3/3 [==============================] - 2s 821ms/step - loss: 0.5657 - accuracy: 0.7500 - val_loss: 0.5642 - val_accuracy: 0.7500
# Epoch 18/30
# 3/3 [==============================] - 2s 856ms/step - loss: 0.5783 - accuracy: 0.7500 - val_loss: 0.6076 - val_accuracy: 0.7500
# Epoch 19/30
# 3/3 [==============================] - 2s 853ms/step - loss: 0.5866 - accuracy: 0.7500 - val_loss: 0.5656 - val_accuracy: 0.7500
# Epoch 20/30
# 3/3 [==============================] - 2s 839ms/step - loss: 0.5699 - accuracy: 0.7500 - val_loss: 0.5642 - val_accuracy: 0.7500
# Epoch 21/30
# 3/3 [==============================] - 2s 837ms/step - loss: 0.5702 - accuracy: 0.7500 - val_loss: 0.5792 - val_accuracy: 0.7500
# Epoch 22/30
# 3/3 [==============================] - 2s 863ms/step - loss: 0.5735 - accuracy: 0.7500 - val_loss: 0.5642 - val_accuracy: 0.7500
# Epoch 23/30
# 3/3 [==============================] - 2s 858ms/step - loss: 0.5683 - accuracy: 0.7500 - val_loss: 0.5708 - val_accuracy: 0.7500
# Epoch 24/30
# 3/3 [==============================] - 2s 842ms/step - loss: 0.5652 - accuracy: 0.7500 - val_loss: 0.5634 - val_accuracy: 0.7500
# Epoch 25/30
# 3/3 [==============================] - 2s 853ms/step - loss: 0.5659 - accuracy: 0.7500 - val_loss: 0.5637 - val_accuracy: 0.7500
# Epoch 26/30
# 3/3 [==============================] - 2s 853ms/step - loss: 0.5633 - accuracy: 0.7500 - val_loss: 0.5649 - val_accuracy: 0.7500
# Epoch 27/30
# 3/3 [==============================] - 2s 826ms/step - loss: 0.5633 - accuracy: 0.7500 - val_loss: 0.5648 - val_accuracy: 0.7500
# Epoch 28/30
# 3/3 [==============================] - 2s 851ms/step - loss: 0.5663 - accuracy: 0.7500 - val_loss: 0.5755 - val_accuracy: 0.7500
# Epoch 29/30
# 3/3 [==============================] - 2s 841ms/step - loss: 0.5776 - accuracy: 0.7500 - val_loss: 0.5664 - val_accuracy: 0.7500
# Epoch 30/30
# 3/3 [==============================] - 2s 814ms/step - loss: 0.5667 - accuracy: 0.7500 - val_loss: 0.5639 - val_accuracy: 0.7500

# %%
#coding d atas adl membangun DL yg bekerja dlm internal representation
#can we interprate the internal representation?
#generally no, but if we work on images and conv neural net, we can interprete what NN has learned through internal representation

#coding di bawah ini akan menunjukkan apa yang telah d pelajari oleh CNN melalui layer Conv2D and MaxPool2D

# %%
import random
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# %%
# Get list of layers from model
layer_outputs = [layer.output for layer in model.layers[1:]]

#it means we will get the layer lis from the first ntill the last

# %%
# Create a visualization model
visualize_model = tf.keras.models.Model(inputs = model.input, outputs = layer_outputs)

# %%
# Load image for prediction
img=load_img('basedata/training/Nin/1.PNG',target_size=(500,500))

# %%
#showing the image
plt.imshow(img)

# %%
# Convert image to array
x = img_to_array(img)

# %%
# Print shape of array
x.shape
# Out:
# (500, 500, 3)

# %%
# Reshape image for passing it to prediction
x=x.reshape((1,500,500,3))
print(x.shape)
# Out:
# (1, 500, 500, 3)

# %%
# Rescale the image
x = x /255 

#di re-scale karena saat training juga di re-scale

# %%
# Get all layers feature maps for image
feature_maps=visualize_model.predict(x)
print(len(feature_maps))
# Out:
# 1/1 [==============================] - 0s 110ms/step
# 8

# %%
# Show names of layers available in model
layer_names = [layer.name for layer in model.layers]
print(layer_names)
# Out:
# ['conv2d', 'max_pooling2d', 'conv2d_1', 'max_pooling2d_1', 'conv2d_2', 'max_pooling2d_2', 'flatten', 'dense', 'dense_1']

# %%
# import required libraries
# %matplotlib inline

# %%
# Plotting the graph
for layer_names, feature_maps in zip(layer_names,feature_maps):
  print(feature_maps.shape)
  if len(feature_maps.shape) == 4 :
    channels = feature_maps.shape[-1]
    size = feature_maps.shape[1]
    display_grid = np.zeros((size, size * channels))
    for i in range(channels):
      x = feature_maps[0, :, :, i]
      x -= x.mean()
      x /= x.std()
      x *= 64
      x += 128
      x = np.clip(x, 0, 255).astype('uint8')
      # We'll tile each filter into this big horizontal grid
      display_grid[:, i * size : (i + 1) * size] = x
    scale = 20. / channels
    plt.figure(figsize=(scale * channels, scale))
    plt.title(layer_names)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
# Out:
# (1, 249, 249, 16)
# (1, 247, 247, 32)
# C:\Users\EIEI\AppData\Local\Temp/ipykernel_5800/1327639601.py:11: RuntimeWarning: invalid value encountered in true_divide
#   x /= x.std()
# (1, 123, 123, 32)
# (1, 121, 121, 64)
# (1, 60, 60, 64)
# (1, 230400)
# (1, 512)
# (1, 1)
